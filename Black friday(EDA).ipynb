# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Reading the data sets.

# %%
## Reading the training dataset.
train = pd.read_csv('C:/Users/Makro_1997/black friday/train.csv')

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
train.shape
# Out:
# (550068, 12)

# %%
##Reading the test dataset.
test = pd.read_csv('C:/Users/Makro_1997/black friday/test.csv')

# %%
test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
test.shape
# Out:
# (233599, 11)

# %% [markdown]
# # Joining two tabels:

# %%
df = pd.concat([train,test],axis=0)

# %%
df.shape
# Out:
# (783667, 12)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
##Drop the unwanted columns.
df.drop(['User_ID'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# # Handling the categerical variable.

# %%
#Handling the Gender variable.
df['Gender'] = df['Gender'].map({'F':0,'M':1})

# %%
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
#Handling Age variable:
df['Age'] = df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df['City_Category'].value_counts()
# Out:
# B    329739
# C    243684
# A    210244
# Name: City_Category, dtype: int64

# %%
city_cat = pd.get_dummies(df['City_Category'])
city_cat.head()
# Out:
#    A  B  C
# 0  1  0  0
# 1  1  0  0
# 2  1  0  0
# 3  1  0  0
# 4  0  0  1

# %%
##Concodinate the data vs pd_get dummies value.
df = pd.concat([df,city_cat],axis=1)
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  A  B  C
# 0                 NaN                 NaN    8370.0  1  0  0
# 1                 6.0                14.0   15200.0  1  0  0
# 2                 NaN                 NaN    1422.0  1  0  0
# ...

# %%
df.drop(['City_Category'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                          2
# 1  P00248942       0    1          10                          2
# 2  P00087842       0    1          10                          2
# 3  P00085442       0    1          10                          2
# 4  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# ...

# %% [markdown]
# # Handling null values:

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# A                                  0
# B                                  0
# C                                  0
# dtype: int64

# %%
df['Product_Category_2'].value_counts()
# Out:
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: Product_Category_2, dtype: int64

# %%
df['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
df['Product_Category_3'].isnull().sum()
# Out:
# 545809

# %%
df['Product_Category_3'].value_counts()
# Out:
# 16.0    46469
# 15.0    39968
# 14.0    26283
# 17.0    23818
# 5.0     23799
# 8.0     17861
# 9.0     16532
# 12.0    13115
# 13.0     7849
# 6.0      6888
# 18.0     6621
# 4.0      2691
# 11.0     2585
# 10.0     2501
# 3.0       878
# Name: Product_Category_3, dtype: int64

# %%
df['Product_Category_3'].mode()[0]
# Out:
# 16.0

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df['Product_Category_3'].isnull().sum()
# Out:
# 0

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].map({'0':0,'1':1,'2':2,'3':3,'4+':4})

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array([2, 4, 3, 1, 0], dtype=int64)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                           2
# 1  P00248942       0    1          10                           2
# 2  P00087842       0    1          10                           2
# 3  P00085442       0    1          10                           2
# 4  P00285442       1    7          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int64
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  A                           783667 non-null  uint8
#  11  B                           783667 non-null  uint8
#  12  C                           783667 non-null  uint8
# ...

# %% [markdown]
# # Converting the diffrent data types into integer values.

# %%
#Converting the uint data types into integer values.
df['A'] = df['A'].astype(int)
df['A'].dtype
# Out:
# dtype('int32')

# %%
df['B'] = df['B'].astype(int)
df['B'].dtype
# Out:
# dtype('int32')

# %%
df['C'] = df['C'].astype(int)
df['C'].dtype
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int64
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  A                           783667 non-null  int32
#  11  B                           783667 non-null  int32
#  12  C                           783667 non-null  int32
# ...

# %%
##Visualization:
plt.figure(figsize=(15,6))
sns.pairplot(df)

# %%
sns.barplot(df['Age'],df['Purchase'],hue=df['Gender'])
# Out:
# C:\Users\Makro_1997\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# #Observations.
#
#     1.male purchase more than women.

# %%
sns.barplot(df['Product_Category_1'],df['Purchase'],hue=df['Gender'])
# Out:
# C:\Users\Makro_1997\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_1', ylabel='Purchase'>

# %%
sns.barplot(df['Product_Category_2'],df['Purchase'],hue = df['Gender'])
# Out:
# C:\Users\Makro_1997\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_2', ylabel='Purchase'>

# %%
sns.barplot(df['Product_Category_3'],df['Purchase'],hue=df['Gender'])
# Out:
# C:\Users\Makro_1997\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_3', ylabel='Purchase'>

# %% [markdown]
# ##Observations:
#
#     1.product_catagory 1 is more purchased then other two Product_catagory.

# %%
df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'A', 'B', 'C'],
#       dtype='object')

# %%
df = df.drop(['Product_ID'],axis=1)

# %%
df.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       0    1          10                           2               0
# 1       0    1          10                           2               0
# 2       0    1          10                           2               0
# 3       0    1          10                           2               0
# 4       1    7          16                           4               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  A  B  \
# 0                   3                 8.0                16.0    8370.0  1  0
# 1                   1                 6.0                14.0   15200.0  1  0
# 2                  12                 8.0                16.0    1422.0  1  0
# 3                  12                14.0                16.0    1057.0  1  0
# 4                   8                 8.0                16.0    7969.0  0  0
#
#    C
# 0  0
# 1  0
# 2  0
# 3  0
# 4  1

# %%
df['Purchase'].isnull().sum()
# Out:
# 233599

# %%
df_train = df[~df['Purchase'].isnull()]
df_train.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       0    1          10                           2               0
# 1       0    1          10                           2               0
# 2       0    1          10                           2               0
# 3       0    1          10                           2               0
# 4       1    7          16                           4               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  A  B  \
# 0                   3                 8.0                16.0    8370.0  1  0
# 1                   1                 6.0                14.0   15200.0  1  0
# 2                  12                 8.0                16.0    1422.0  1  0
# 3                  12                14.0                16.0    1057.0  1  0
# 4                   8                 8.0                16.0    7969.0  0  0
#
#    C
# 0  0
# 1  0
# 2  0
# 3  0
# 4  1

# %%
df_test = df[df['Purchase'].isnull()]
df_test.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       1    5           7                           2               1
# 1       1    3          17                           0               0
# 2       0    4           1                           4               1
# 3       0    4           1                           4               1
# 4       0    3           1                           1               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase  A  B  \
# 0                   1                11.0                16.0       NaN  0  1
# 1                   3                 5.0                16.0       NaN  0  0
# 2                   5                14.0                16.0       NaN  0  1
# 3                   4                 9.0                16.0       NaN  0  1
# 4                   4                 5.0                12.0       NaN  0  0
#
#    C
# 0  0
# 1  1
# 2  0
# 3  0
# 4  1

# %%
#Split the depedenent and independent variables from the data set.

x = df_train.drop(['Purchase'],axis=1)
x.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       0    1          10                           2               0
# 1       0    1          10                           2               0
# 2       0    1          10                           2               0
# 3       0    1          10                           2               0
# 4       1    7          16                           4               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  A  B  C
# 0                   3                 8.0                16.0  1  0  0
# 1                   1                 6.0                14.0  1  0  0
# 2                  12                 8.0                16.0  1  0  0
# 3                  12                14.0                16.0  1  0  0
# 4                   8                 8.0                16.0  0  0  1

# %%
x.shape
# Out:
# (550068, 11)

# %%
y = df_train['Purchase']
y.head()
# Out:
# 0     8370.0
# 1    15200.0
# 2     1422.0
# 3     1057.0
# 4     7969.0
# Name: Purchase, dtype: float64

# %%
y.shape
# Out:
# (550068,)

# %%
#Split the train test split.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
x_train.shape
# Out:
# (412551, 11)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
##Build a model.
